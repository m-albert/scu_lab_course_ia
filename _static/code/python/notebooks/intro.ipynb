# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from iaf.notebook import init_style
init_style()
# Out:
#     <style>
#     .container {
#         width: 90% !important;
#     }
#
#     #notebook-container {
#         box-shadow: none !important;
#         background-color: white;
#     }
#
#     div.input_area {
#         border: none;
#         border-radius: 0;
#         background: #f7f7f7;
#         line-height: 1.5em;
#         margin: 0.5em 0;
#         padding: 0;
#     }
#
#     div.cell {
#         transition: all 0.25s;
#         border: none;
#         position: relative;
#         top: 0;
#     }
#
#     div.cell.selected, div.cell.selected.jupyter-soft-selected {
#         border: none;
#         background: transparent;
#         box-shadow: 0 6px 18px #aaa;
#         z-index: 10;
#         top: -10px;
#     }
#
#     .rendered_html p, ul {
#         line-height: 1.5em;
#         font-size: 16px;
#     }
#
#     .output_png {
#         display: table-cell;
#         text-align: center;
#         vertical-align: middle;
#     }
#
#     </style>

# %% [markdown]
# # A simple class (Object-Oriented Programming)

# %% [markdown]
# ## Class definition

# %%
class Car:
    """A simple class representing a Car."""
    def __init__(self, make="VW", year=2021):
        """Constructor."""     
        self.make = make
        self.year = year
        self.is_on = False
        self.speed = 0.0
        
    def __repr__(self):
        """String representation of the object."""
        if self.is_on:
            return f"{self.make} ({self.year}): engine is on and speed is {self.speed}."
        else:
            return f"{self.make} ({self.year}): engine is off."           
    
    def turn_on(self):
        """Turn on the Car."""
        self.is_on = True
    
    def turn_off(self):
        """Turn off the Car."""
        
        # We can only turn off the car, if the speed is 0!
        if self.speed > 0.0:
            print("Stop the car first!")
        else:
            self.is_on = False
    
    def accelerate(self, new_speed):
        """Accelerate to the new speed."""
        
        # We can only accelerate if the Car is on
        if not self.is_on:
            print("Turn on the car first!")
        else: 
            self.speed = new_speed
            if self.speed > 250.0:
                print("Maximum car speed (250.0) reached!")
                self.speed = 250.0
                
    def brake(self):
        """Brake."""
        
        # We can only brake if the car is on and moving!
        if not self.is_on:
            print("The car is off!")
            return
        
        if self.speed == 0.0:
            print("The car is not moving!")
            return
        
        # Okay, we can brake
        self.speed = 0.0

# %% [markdown]
# ## A test driver

# %%
car = Car()
car    # This calls car.__repr__()
# Out:
# VW (2021): engine is off.

# %%
car.accelerate(100.0)
# Out:
# Turn on the car first!

# %%
car.turn_on()
car
# Out:
# VW (2021): engine is on and speed is 0.0.

# %%
car.brake()
# Out:
# The car is not moving!

# %%
car.accelerate(100.0)
car
# Out:
# VW (2021): engine is on and speed is 100.0.

# %%
car.accelerate(300.0)
# Out:
# Maximum car speed (250.0) reached!

# %%
car
# Out:
# VW (2021): engine is on and speed is 250.0.

# %%
car.turn_off()
# Out:
# Stop the car first!

# %%
car.brake()
car
# Out:
# VW (2021): engine is on and speed is 0.0.

# %%
car.turn_off()
car
# Out:
# VW (2021): engine is off.

# %% [markdown]
# # Playground

# %% [markdown]
# Use this space if you want to play with Numpy, Pandas or Matplotlib.

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
x_col = "sepal length (cm)"
y_col = "sepal width (cm)"
categories = df["species"].astype('category').cat
codes = categories.codes
labels = list(categories.categories)

s = plt.scatter(x=df[x_col], y=df[y_col], c=codes)
plt.legend(handles=s.legend_elements()[0], labels=labels, title="species")
plt.xlabel(x_col)
plt.ylabel(y_col);
