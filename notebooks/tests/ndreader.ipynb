# %%
import nd2
import numpy as np

# %%
filename = '/Users/albertm/teaching/lab_course/data/plate01.nd2'

my_array = nd2.imread(
    filename,
    dask=True,
    )[0].compute()

# %%
f = nd2.ND2File(filename)
f.voxel_size()
