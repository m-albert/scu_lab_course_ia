# %% [markdown]
# # Exercise: Segmentation Using Shallow Learning
#
# In this exercise, we will explore segmentation using a pre-trained Weka model and compare it with a newly trained model. We will also investigate the effect of background subtraction on segmentation results.
#
# 1. Load the segmentation mask with the `classifier.model` and filter the segmentation artefacts. Print number of cells before and after cleaning the mask.
# 2. Train a new Weka model in ImageJ/Fiji on the image `cells_shaded.tif` and in python load this new model and compare the segmentation masks to the old model `classifier.model` visually and count the objects.
# 3. Substract the background first and compare the mask and object count to point 2.

# %%
from IPython.display import FileLink, display

print('Download model and images here:')
display(FileLink('illustrations/classifier.model'))
display(FileLink('illustrations/cells_shaded.tif'))
display(FileLink('illustrations/blobs_ml_seg.png'))
# Out:
# Download model and images here:
# c:\Users\Localadmin\ownCloud\Projects\Collaborations\Marvin\scu_lab_course_ia\notebooks\illustrations\classifier.model
# c:\Users\Localadmin\ownCloud\Projects\Collaborations\Marvin\scu_lab_course_ia\notebooks\illustrations\cells_shaded.tif
# c:\Users\Localadmin\ownCloud\Projects\Collaborations\Marvin\scu_lab_course_ia\notebooks\illustrations\blobs_ml_seg.png
