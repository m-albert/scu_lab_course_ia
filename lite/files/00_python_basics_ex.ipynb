# %% [markdown]
# # Exercise: Python Basics
#
# **Duration** ~45 min &nbsp;·&nbsp; **Session** Day 0, at home
#
# These tasks follow the order of the walkthrough notebook `00_python_basics`. If you need to review a
# concept, return to the matching section of the walkthrough. Open the hints in
# order when you need them.
#
# **Data**: none. The exercises use values created in the notebook.

# %% [markdown]
# ## Task 1: variables and f-strings
#
# You counted 34 objects; the expert annotation says 39.
#
# Print one line reading exactly:
#
# ```
# found 34 of 39 objects (87.2%)
# ```
#
# <details>
# <summary>Hint 1</summary>
#
# Store both numbers in variables, then build the sentence with an f-string.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# A fraction formatted as a percentage to one decimal place is `{value:.1%}`, and
# `value` here is `found / truth`.
# </details>

# %%
# --- your turn ---
found = ...
truth = ...

print(...)   # TODO: one line, with the percentage formatted to 1 decimal

# %% [markdown]
# ## Task 2: lists
#
# Here are the areas of eight objects.
#
# Print the number of objects, the smallest and largest area, and the average.
# Then print the **first three** areas and the **last** one.
#
# <details>
# <summary>Hint 1</summary>
#
# `len()`, `min()`, `max()` and `sum()` all take a list.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# The average is `sum(areas) / len(areas)`. The first three are `areas[:3]` and the
# last is `areas[-1]`.
# </details>

# %%
areas = [236, 512, 480, 1305, 390, 875, 61, 505]

# --- your turn ---
print(f"{...} objects")
print(f"smallest : {...}")
print(f"largest  : {...}")
print(f"average  : {...:.1f}")
print(f"first three : {...}")
print(f"last        : {...}")

# %% [markdown]
# ## Task 3: loops and decisions
#
# Go through `areas` and print one line per object saying whether it is
# `too small` (under 100), `too big` (over 1000) or `plausible`.
#
# Then print how many were plausible.
#
# <details>
# <summary>Hint 1</summary>
#
# A `for` loop with an `if` / `elif` / `else` inside it. Remember the indentation.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Keep a counter: set `plausible = 0` before the loop and `plausible += 1` inside
# the branch that matches.
# </details>

# %%
# --- your turn ---
plausible = 0

for area in areas:
    if ...:
        verdict = "too small"
    elif ...:
        verdict = "too big"
    else:
        verdict = "plausible"
        ...
    print(f"{area:5d} px  ->  {verdict}")

print(f"{plausible} of {len(areas)} are plausible")

# %% [markdown]
# ## Task 4: zip
#
# Each area has a name. Print them paired up, one per line, with the names lined up
# in a column.
#
# <details>
# <summary>Hint</summary>
#
# `for name, area in zip(names, areas):`. To line the names up, format them with a
# width: `{name:10s}`.
# </details>

# %%
names = ["nucleus", "nucleus", "nucleus", "clump", "nucleus", "clump", "debris", "nucleus"]

# --- your turn ---
for ... in zip(...):
    print(...)

# %% [markdown]
# ## Task 5: a function
#
# Write `classify(area, smallest=100, largest=1000)` that returns the same three
# verdicts as task 3. Then check it on a few values.
#
# <details>
# <summary>Hint 1</summary>
#
# ```python
# def classify(area, smallest=100, largest=1000):
#     ...
#     return "plausible"
# ```
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# `return` immediately ends the function, so you do not need `else` after a
# `return`.
# </details>

# %%
# --- your turn ---
def classify(area, smallest=100, largest=1000):
    ...   # TODO

print(classify(61))
print(classify(505))
print(classify(1305))
print(classify(61, smallest=20))     # the default overridden

# %% [markdown]
# ## Task 6: build an array and describe it
#
# Make a 6x8 array of random whole numbers between 0 and 100, then print its
# shape, dtype, smallest value, largest value and mean.
#
# <details>
# <summary>Hint</summary>
#
# `rng.integers(0, 100, size=(6, 8))` gives the array. Then `.shape`, `.dtype`,
# `.min()`, `.max()`, `.mean()`.
# </details>

# %%
import numpy as np

rng = np.random.default_rng(0)      # fixed seed, so your numbers match ours

# --- your turn ---
image = ...   # TODO: 6 rows, 8 columns, values 0-99

print(image)
print(f"shape    : {...}")
print(f"dtype    : {...}")
print(f"smallest : {...}")
print(f"largest  : {...}")
print(f"mean     : {...:.1f}")

# %% [markdown]
# ## Task 7: indexing and cropping
#
# From your array, print:
#
# 1. the pixel at row 2, column 3;
# 2. row 0 in full;
# 3. column 5 in full;
# 4. a crop of rows 1-3 and columns 2-5, and its shape.
#
# <details>
# <summary>Hint</summary>
#
# `image[2, 3]`, `image[0]`, `image[:, 5]`, `image[1:4, 2:6]`. Remember the stop
# index is not included, so rows 1-3 is `1:4`.
# </details>

# %%
# --- your turn ---
print("pixel (2, 3) :", ...)
print("row 0        :", ...)
print("column 5     :", ...)

crop = ...
print(crop)
print("crop shape:", crop.shape)

# %% [markdown]
# ## Task 8: masks
#
# Make a mask of the pixels above 50. Print how many there are, what fraction of
# the image that is, and the average value **of just those pixels**.
#
# Then make a copy of the image with everything below 50 set to zero.
#
# <details>
# <summary>Hint 1</summary>
#
# `mask = image > 50`. Since `True` counts as 1, `mask.sum()` counts them and
# `mask.mean()` gives the fraction.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# `image[mask]` selects just those values. For the last part use `.copy()` first,
# then assign with the *opposite* mask: `copy[~mask] = 0` (`~` means "not").
# </details>

# %%
# --- your turn ---
mask = ...

print(f"above 50      : {...} pixels")
print(f"that is       : {...:.1%} of the image")
print(f"their average : {...:.1f}")

copy = ...        # TODO: a real copy
copy[...] = 0     # TODO: zero everything NOT in the mask
print(copy)

# %% [markdown]
# **Your answer:** why does the walkthrough insist on `.copy()` here?
# *(edit this cell)*

# %% [markdown]
# ## Task 9: three panels
#
# Draw a figure with three panels side by side: the image, the mask, and a
# histogram of the image's values.
#
# <details>
# <summary>Hint 1</summary>
#
# `fig, axes = plt.subplots(1, 3, figsize=(11, 3))`, then use `axes[0]`, `axes[1]`
# and `axes[2]`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Images go in with `axes[0].imshow(image, cmap="gray")`; the histogram needs the
# values flattened, `axes[2].hist(image.ravel(), bins=20)`.
# </details>

# %%
import matplotlib.pyplot as plt

# --- your turn ---
fig, axes = plt.subplots(1, 3, figsize=(11, 3))

...   # TODO: image, mask, histogram

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Task 10: a table
#
# Build a `DataFrame` from `areas` and `names`, then:
#
# 1. show it;
# 2. print the average area;
# 3. show only the rows with an area above 450;
# 4. print the median area for each `kind`.
#
# <details>
# <summary>Hint 1</summary>
#
# `pd.DataFrame({"area": areas, "kind": names})`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# Filtering is `table[table["area"] > 450]`, and the grouped summary is
# `table.groupby("kind")["area"].median()`.
# </details>

# %%
import pandas as pd

# --- your turn ---
table = ...   # TODO

print(table)
print(f"average area: {...:.1f}")
print(table[...])                 # TODO: rows with area above 450
print(table.groupby(...))         # TODO: median area per kind

# %% [markdown]
# ## Task 11: put it together
#
# Using `classify` from task 5, add a `verdict` column to the table and count how
# many objects fall in each verdict.
#
# <details>
# <summary>Hint 1</summary>
#
# A list comprehension applies the function to every area:
# `[classify(a) for a in table["area"]]`.
# </details>
#
# <details>
# <summary>Hint 2</summary>
#
# `table["verdict"].value_counts()` counts each distinct value.
# </details>

# %%
# --- your turn ---
table["verdict"] = ...   # TODO: classify every area

print(table)
print(table["verdict"]...)   # TODO: count each verdict

# %% [markdown]
# ## If you finish early
#
# Two things worth trying, because they are the mistakes that cost people time:
#
# 1. Run `a = np.array([1, 2, 3])`, then `b = a`, then `b[0] = 99`. Print `a`.
#    Were you expecting that? Now try it with `b = a.copy()`.
#
# 2. In a fresh cell write `x = 5`. Run it. Now change it to `x = 10` but **do not
#    run it**, and in the next cell print `x`. What do you get, and why?
#
# If both of those surprised you, reread the warning in section 12 and the tip in
# section 1: between them they explain most of the confusing behaviour you will
# hit in a notebook.
